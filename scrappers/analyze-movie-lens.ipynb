# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

#import numpy as np # linear algebra
#0import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
 #   for filename in filenames:
  #      print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

# %%
df_ratings = pd.read_csv("/kaggle/input/datasets/organizations/grouplens/movielens-20m-dataset/rating.csv")

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
df_ratings.drop("timestamp", axis=1, inplace = True)

# %%
df_ratings.to_csv("ratings.csv", index=False)

# %%
df_movie = pd.read_csv("/kaggle/input/datasets/organizations/grouplens/movielens-20m-dataset/movie.csv")

# %%
df_movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_movie[["movie_name", "year"]] = df_movie["title"].str.extract(r'^(.*)\s\((\d{4})\)$')

print(df_movie.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres                   movie_name  \
# 0  Adventure|Animation|Children|Comedy|Fantasy                    Toy Story
# 1                   Adventure|Children|Fantasy                      Jumanji
# 2                               Comedy|Romance             Grumpier Old Men
# 3                         Comedy|Drama|Romance            Waiting to Exhale
# 4                                       Comedy  Father of the Bride Part II
#
#    year
# 0  1995
# 1  1995
# 2  1995
# 3  1995
# 4  1995

# %%
#df_movie.drop("year", axis=1, inplace=True)

# %%
df_movie["genres"] = df_movie["genres"].str.split("|")

# %%
df_movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]
#
#                     movie_name  year
# 0                    Toy Story  1995
# 1                      Jumanji  1995
# 2             Grumpier Old Men  1995
# 3            Waiting to Exhale  1995
# 4  Father of the Bride Part II  1995

# %%
df_movie.drop("title", axis=1, inplace=True)

# %%
df_movie.to_csv("movies.csv", index=False)

# %%
df_tag = pd.read_csv("/kaggle/input/datasets/organizations/grouplens/movielens-20m-dataset/tag.csv")

# %%
df_tag.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18
